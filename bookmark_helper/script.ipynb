# %%
from collect_data import request_info

# %%
url="https://www.decathlon.com.au/"

# %%
request_info(url, timeout=10000)
# Out:
# Title not found: https://www.decathlon.com.au/

# %%
import requests
from requests.exceptions import Timeout
import bs4

# %%
r = requests.get(url)

# %%
r.text
# Out:
# '<!DOCTYPE html><html lang="en-AU"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, user-scalable=no"/><link rel="shortcut icon" href="https://contents.mediadecathlon.com/s1069013/k$10866d2297acbeec9a8aac5976870392/apacc%20vp%20favicon.png?format=auto"/><link rel="preconnect" href="/v2/en-AU"/><link rel="preconnect" href="/v2/en-AU"/><link rel="preconnect" href="https://www.googletagmanager.com"/><meta name="next-head-count" content="6"/><link data-next-font="" rel="preconnect" href="/" crossorigin="anonymous"/><link rel="preload" href="/_next/static/css/ef6e516f70023d49.css" as="style"/><link rel="stylesheet" href="/_next/static/css/ef6e516f70023d49.css" data-n-g=""/><link rel="preload" href="/_next/static/css/c6fc93ff02402b1e.css" as="style"/><link rel="stylesheet" href="/_next/static/css/c6fc93ff02402b1e.css" data-n-p=""/><noscript data-n-css=""></noscript><script defer="" nomodule="" src="/_next/static/chunks/polyfills-c67a75d1b6f99dc8.js"></script><script src="/_next/static/chunks/webpack-759fb7cfa7da5c04.js" defer=""></script><script src="/_next/static/chunks/framework-ca706bf673a13738.js" defer=""></script><script src="/_next/static/chunks/main-fb9284e98b48ba61.js" defer=""></script><script src="/_next/static/chunks/pages/_app-4268c1e08c237834.js" defer=""></script><script src="/_next/static/chunks/966dc764-0e3fa883afbb5e39.js" defer=""></script><script src="/_next/static/chunks/795-f50f179d5f11b79b.js" defer=""></script><script src="/_next/static/chunks/2686-60ed061fc609d13d.js" defer=""></script><script src="/_next/static/chunks/294-9d6488c5ed7e01e9.js" defer=""></script><script src="/_next/static/chunks/7898-a76c561dac0785b4.js" defer=""></script><script src="/_next/static/chunks/8764-c3a7cfc05a737b3f.js" defer=""></script><script src="/_next/static/chunks/5336-d69ab4cd1b65f823.js" defer=""></script><script src="/_next/static/chunks/1664-e60a2d44be35c200.js" defer=""></script><script src="/_next/static/chunks/9669-2e59473a960e5f09.js" defer=""></script><script src="/_next/static/chunks/6423-2a01ca71b1f94eac.js" defer=""></script><script src="/_next/static/chunks/68-145f011f16d0e7d4.js" defer=""></script><script src="/_next/static/chunks/5680-ad6974e32bc9369c.js" defer=""></script><script src="/_next/static/chunks/9767-4842e00e72fd08d7.js" defer=""></script><script src="/_next/static/chunks/5827-ec42bfb28048879e.js" defer=""></script><script src="/_next/static/chunks/943-ffe5e7fa55138cc4.js" defer=""></script><script src="/_next/static/chunks/pages/index-41ccb999a788be6f.js" defer=""></script><script src="/_next/static/psc4zAxk3P_AgArM_tY0C/_buildManifest.js" defer=""></script><script src="/_next/static/psc4zAxk3P_AgArM_tY0C/_ssgManifest.js" defer=""></script></head><body><noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-P48Q7VMP" height="0" width="0" style="display:none;visibility:hidden"></iframe><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-5Q2NT577" height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript><div id="__next"><style data-emotion="css-global v9s7s1">html{--theme-ui-colors-text:var(--vp-semantic-color-content-neutral);--theme-ui-colors-background:var(--vp-semantic-color-background-main);--theme-ui-colors-primary:var(--vp-semantic-color-content-brand);color:var(--theme-ui-colors-text);background-color:var(--theme-ui-colors-background);}</style><style data-emotion="css-global w8u8tp">*{box-sizing:border-box;}html{font-family:Roboto,sans-serif;}body{margin:0;}</style><style data-emotion-css="xg5s2c">.css-xg5s2c{box-sizing:border-box;max-height:100%;max-width:100%;overflow:hidden;padding:8px;pointer-events:none;position:fixed;z-index:1000;top:0;right:0;}</style><div class="react-toast-notifications__container css-xg5s2c"></div></div><div id="modal"></div><script id="__NEXT_DATA__" type="application/json">{"props":{"pageProps":{"dehydratedState":{"mutations":[],"queries":[{"state":{"data":"en","dataUpda ...

# %%
r.encoding
# Out:
# 'utf-8'

# %%
encoding = "gb18030"
if r.encoding == 'ISO-8859-1':
    r.encoding = 'utf-8'

# %%
# r.encoding = 'utf-8' 
soup = bs4.BeautifulSoup(r.text, 'html.parser', from_encoding=encoding)
soup.title.string
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[57], line 3
#       1 # r.encoding = 'utf-8'
#       2 soup = bs4.BeautifulSoup(r.text, 'html.parser', from_encoding=encoding)
# ----> 3 soup.title.string
#
# AttributeError: 'NoneType' object has no attribute 'string'

# %%
# 获取网页中的所有文本
page_text = soup.get_text(separator=' ', strip=True)

# 获取前 100 个字符
page_text[:1000]
# Out:
# ''
